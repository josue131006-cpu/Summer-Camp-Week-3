# %% [markdown]
# <a href="https://colab.research.google.com/github/josue131006-cpu/Summer-Camp-Week-3/blob/main/Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Summer Camp 2026")
# Out:
# Summer Camp 2026

# %%
jugador = "R.O.B"
print(jugador,"Ha entrado en la arena")
jugador2 = "Mario"
print(jugador2,"se ha caido del escenario")
# Out:
# R.O.B Ha entrado en la arena
# Mario se ha caido del escenario
